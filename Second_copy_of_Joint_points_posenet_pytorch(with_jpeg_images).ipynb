# %% [markdown]
# <a href="https://colab.research.google.com/github/Soumi7/Tflite_model/blob/master/Second_copy_of_Joint_points_posenet_pytorch(with_jpeg_images).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Soumi7/posenet-pytorch.git
# Out:
# Cloning into 'posenet-pytorch'...
# remote: Enumerating objects: 272, done.
# remote: Counting objects: 100% (272/272), done.
# remote: Compressing objects: 100% (263/263), done.
# remote: Total 387 (delta 22), reused 258 (delta 8), pack-reused 115
# Receiving objects: 100% (387/387), 22.57 MiB | 17.35 MiB/s, done.
# Resolving deltas: 100% (83/83), done.

# %%
pip install torchvision

# %%
pip install requests opencv-python==3.4.5.20
# Out:
# ...
#      |████████████████████████████████| 25.4MB 119kB/s
# ...
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# ...

# %%
# %cd posenet-pytorch
# !ls
# Out:
# /content/posenet-pytorch
# benchmark.py	    LICENSE.txt  README.md  triangle3
# get_test_images.py  NOTICE.txt	 triangle1  webcam_demo.py
# image_demo.py	    posenet	 triangle2

# %%
# !python image_demo.py --model 101 --image_dir /content/posenet-pytorch/triangle1 --output_dir /content/posenet-pytorch/output
# Out:
# Cannot find models file ./_models/mobilenet_v1_101.pth, converting from tfjs...
# Weights for checkpoint mobilenet_v1_101 are not downloaded. Downloading to /tmp/_posenet_weights ...
# ...
#
# Results for image: /content/posenet-pytorch/triangle1/download (11).jpeg
# [array([ 39.93610503, 127.03541273]), array([ 37.69776357, 128.08660646]), array([ 37.87898256, 125.75563017]), array([ 41.29238135, 130.63998314]), array([ 39.15253762, 125.70554761]), array([ 49.04874079, 135.43698032]), array([ 44.6836027 , 114.45385587]), array([ 38.09547497, 147.24605297]), array([30.97015058, 96.45949549]), array([ 27.14933187, 138.08600316]), array([18.59826105, 86.78523438]), array([ 95.0676086 , 136.25843963]), array([ 93.79494992, 118.25385437]), array([133.31825546, 143.37292583]), array([134.56653913, 109.50856113]), array([156.89940107, 152.76914246]), array([162.65294583, 104.69394883])]
#
# Results for image: /content/posenet-pytorch/triangle1/images (16).jpeg
# ...
